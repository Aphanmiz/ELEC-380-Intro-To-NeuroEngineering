# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# The data for this problem come from CRCNS.org. They come from an experiment in which
# 10 neurons in visual cortex of a cat were recorded during presentation of oriented
# drifting bars. Each stimulus presentation is 4 seconds long, and there are 144
# (8 each for 18 different orientation angles).

with open('problem_3.npy', 'rb') as loadfile:
    stim_direction = np.load(loadfile, allow_pickle=True) # The stimulus direction for each trial in a 144 element vector
    spiketrains = np.load(loadfile, allow_pickle=True) # Raw data of spike times for each trial. Organized as a 10 element array (# of neurons) of 144 element arrays (# of trials) of numpy arrays (spike times)

# %%
# Calculate the spike counts for each neuron for each trial

spike_counts = np.zeros((len(stim_direction), len(spiketrains))) # Number of spikes per trial in a 144 X 10 matrix
for n, neuron in enumerate(spiketrains):
    for t, trial in enumerate(neuron): # iterate over rows
        spike_counts[t,n] = len(trial)
        print("trail", trail)
        print("t", t, "n", n, "value", spike_counts[t,n])
print(spike_counts)
# Out:
# t 0 n 0 value 16.0
# t 1 n 0 value 8.0
# t 2 n 0 value 13.0
# t 3 n 0 value 4.0
# t 4 n 0 value 4.0
# t 5 n 0 value 33.0
# t 6 n 0 value 10.0
# t 7 n 0 value 39.0
# t 8 n 0 value 14.0
# t 9 n 0 value 40.0
# t 10 n 0 value 18.0
# t 11 n 0 value 13.0
# t 12 n 0 value 26.0
# t 13 n 0 value 17.0
# t 14 n 0 value 76.0
# t 15 n 0 value 11.0
# t 16 n 0 value 19.0
# t 17 n 0 value 30.0
# t 18 n 0 value 14.0
# t 19 n 0 value 27.0
# t 20 n 0 value 11.0
# t 21 n 0 value 26.0
# t 22 n 0 value 15.0
# t 23 n 0 value 13.0
# t 24 n 0 value 56.0
# t 25 n 0 value 6.0
# t 26 n 0 value 0.0
# t 27 n 0 value 43.0
# t 28 n 0 value 6.0
# t 29 n 0 value 53.0
# t 30 n 0 value 7.0
# t 31 n 0 value 30.0
# t 32 n 0 value 2.0
# t 33 n 0 value 3.0
# t 34 n 0 value 4.0
# t 35 n 0 value 16.0
# t 36 n 0 value 14.0
# t 37 n 0 value 54.0
# t 38 n 0 value 3.0
# t 39 n 0 value 16.0
# t 40 n 0 value 10.0
# t 41 n 0 value 14.0
# t 42 n 0 value 7.0
# t 43 n 0 value 5.0
# t 44 n 0 value 11.0
# t 45 n 0 value 16.0
# t 46 n 0 value 7.0
# t 47 n 0 value 22.0
# t 48 n 0 value 8.0
# t 49 n 0 value 6.0
# t 50 n 0 value 69.0
# t 51 n 0 value 15.0
# t 52 n 0 value 6.0
# t 53 n 0 value 49.0
# t 54 n 0 value 1.0
# t 55 n 0 value 41.0
# t 56 n 0 value 10.0
# t 57 n 0 value 9.0
# t 58 n 0 value 6.0
# t 59 n 0 value 13.0
# t 60 n 0 value 9.0
# t 61 n 0 value 19.0
# t 62 n 0 value 16.0
# t 63 n 0 value 31.0
# t 64 n 0 value 9.0
# t 65 n 0 value 8.0
# t 66 n 0 value 34.0
# t 67 n 0 value 11.0
# t 68 n 0 value 8.0
# t 69 n 0 value 66.0
# t 70 n 0 value 37.0
# t 71 n 0 value 5.0
# t 72 n 0 value 9.0
# t 73 n 0 value 42.0
# t 74 n 0 value 17.0
# t 75 n 0 value 13.0
# t 76 n 0 value 48.0
# t 77 n 0 value 4.0
# t 78 n 0 value 12.0
# t 79 n 0 value 10.0
# t 80 n 0 value 5.0
# t 81 n 0 value 6.0
# t 82 n 0 value 19.0
# t 83 n 0 value 7.0
# t 84 n 0 value 54.0
# t 85 n 0 value 7.0
# t 86 n 0 value 5.0
# t 87 n 0 value 19.0
# t 88 n 0 value 2.0
# t 89 n 0 value 8.0
# t 90 n 0 value 7.0
# t 91 n 0 value 5.0
# t 92 n 0 value 3.0
# t 93 n 0 value 6.0
# t 94 n 0 value 13.0
# t 95 n 0 value 14.0
# t 96 n 0 value 2.0
# t 97 n 0 value 4.0
# t 98 n 0 value 5.0
# t 99 n 0 value 47.0
# t 100 n 0 value 12.0
# t 101 n 0 value 5.0
# t 102 n 0 value 11.0
# t 103 n 0 value 14.0
# t 104 n 0 value 20.0
# t 105 n 0 value 0.0
# t 106 n 0 value 58.0
# t 107 n 0 value 26.0
# t 108 n 0 value 3.0
# t 109 n 0 value 58.0
# t 110 n 0 value 10.0
# t 111 n 0 value 12.0
# t 112 n 0 value 34.0
# t 113 n 0 value 16.0
# t 114 n 0 value 3.0
# t 115 n 0 value 7.0
# t 116 n 0 value 14.0
# t 117 n 0 value 42.0
# t 118 n 0 value 3.0
# t 119 n 0 value 1.0
# t 120 n 0 value 1.0
# t 121 n 0 value 2.0
# t 122 n 0 value 0.0
# t 123 n 0 value 0.0
# t 124 n 0 value 15.0
# t 125 n 0 value 27.0
# t 126 n 0 value 5.0
# t 127 n 0 value 8.0
# t 128 n 0 value 21.0
# t 129 n 0 value 13.0
# t 130 n 0 value 7.0
# t 131 n 0 value 47.0
# t 132 n 0 value 21.0
# t 133 n 0 value 6.0
# t 134 n 0 value 30.0
# t 135 n 0 value 3.0
# t 136 n 0 value 13.0
# t 137 n 0 value 8.0
# t 138 n 0 value 34.0
# t 139 n 0 value 4.0
# t 140 n 0 value 8.0
# t 141 n 0 value 13.0
# t 142 n 0 value 18.0
# t 143 n 0 value 19.0
# t 0 n 1 value 4.0
# t 1 n 1 value 1.0
# t 2 n 1 value 29.0
# t 3 n 1 value 7.0
# t 4 n 1 value 20.0
# t 5 n 1 value 22.0
# t 6 n 1 value 4.0
# t 7 n 1 value 97.0
# t 8 n 1 value 9.0
# t 9 n 1 value 12.0
# t 10 n 1 value 16.0
# t 11 n 1 value 4.0
# t 12 n 1 value 47.0
# t 13 n 1 value 2.0
# t 14 n 1 value 69.0
# t 15 n 1 value 2.0
# t 16 n 1 value 0.0
# t 17 n 1 value 28.0
# t 18 n 1 value 16.0
# t 19 n 1 value 6.0
# t 20 n 1 value 5.0
# t 21 n 1 value 11.0
# t 22 n 1 value 6.0
# t 23 n 1 value 51.0
# t 24 n 1 value 92.0
# t 25 n 1 value 6.0
# t 26 n 1 value 5.0
# t 27 n 1 value 107.0
# t 28 n 1 value 7.0
# t 29 n 1 value 27.0
# t 30 n 1 value 19.0
# t 31 n 1 value 55.0
# t 32 n 1 value 25.0
# t 33 n 1 value 2.0
# t 34 n 1 value 2.0
# t 35 n 1 value 9.0
# t 36 n 1 value 55.0
# t 37 n 1 value 114.0
# t 38 n 1 value 7.0
# t 39 n 1 value 6.0
# t 40 n 1 value 4.0
# t 41 n 1 value 52.0
# t 42 n 1 value 3.0
# t 43 n 1 value 4.0
# t 44 n 1 value 22.0
# t 45 n 1 value 11.0
# t 46 n 1 value 8.0
# t 47 n 1 value 29.0
# t 48 n 1 value 26.0
# t 49 n 1 value 4.0
# t 50 n 1 value 68.0
# t 51 n 1 value 25.0
# t 52 n 1 value 9.0
# t 53 n 1 value 22.0
# t 54 n 1 value 9.0
# t 55 n 1 value 123.0
# t 56 n 1 value 55.0
# t 57 n 1 value 4.0
# t 58 n 1 value 20.0
# t 59 n 1 value 17.0
# t 60 n 1 value 3.0
# t 61 n 1 value 3.0
# t 62 n 1 value 72.0
# t 63 n 1 value 11.0
# t 64 n 1 value 11.0
# t 65 n 1 value 12.0
# t 66 n 1 value 28.0
# t 67 n 1 value 47.0
# t 68 n 1 value 11.0
# t 69 n 1 value 87.0
# t 70 n 1 value 28.0
# t 71 n 1 value 3.0
# t 72 n 1 value 25.0
# t 73 n 1 value 33.0
# t 74 n 1 value 26.0
# t 75 n 1 value 78.0
# t 76 n 1 value 126.0
# t 77 n 1 value 3.0
# t 78 n 1 value 14.0
# t 79 n 1 value 20.0
# t 80 n 1 value 4.0
# t 81 n 1 value 5.0
# t 82 n 1 value 13.0
# t 83 n 1 value 37.0
# t 84 n 1 value 71.0
# t 85 n 1 value 6.0
# t 86 n 1 value 2.0
# t 87 n 1 value 27.0
# t 88 n 1 value 15.0
# t 89 n 1 value 42.0
# t 90 n 1 value 38.0
# t 91 n 1 value 9.0
# t 92 n 1 value 14.0
# t 93 n 1 value 5.0
# t 94 n 1 value 8.0
# t 95 n 1 value 67.0
# t 96 n 1 value 5.0
# t 97 n 1 value 2.0
# t 98 n 1 value 10.0
# t 99 n 1 value 122.0
# t 100 n 1 value 64.0
# t 101 n 1 value 16.0
# t 102 n 1 value 5.0
# t 103 n 1 value 17.0
# t 104 n 1 value 10.0
# t 105 n 1 value 7.0
# t 106 n 1 value 87.0
# t 107 n 1 value 28.0
# t 108 n 1 value 4.0
# t 109 n 1 value 71.0
# t 110 n 1 value 8.0
# t 111 n 1 value 78.0
# t 112 n 1 value 95.0
# t 113 n 1 value 61.0
# t 114 n 1 value 37.0
# t 115 n 1 value 13.0
# t 116 n 1 value 6.0
# t 117 n 1 value 13.0
# t 118 n 1 value 14.0
# t 119 n 1 value 5.0
# t 120 n 1 value 2.0
# t 121 n 1 value 7.0
# t 122 n 1 value 1.0
# t 123 n 1 value 8.0
# t 124 n 1 value 15.0
# t 125 n 1 value 3.0
# t 126 n 1 value 11.0
# t 127 n 1 value 32.0
# t 128 n 1 value 40.0
# t 129 n 1 value 5.0
# t 130 n 1 value 9.0
# t 131 n 1 value 75.0
# t 132 n 1 value 6.0
# t 133 n 1 value 12.0
# t 134 n 1 value 86.0
# t 135 n 1 value 13.0
# t 136 n 1 value 38.0
# t 137 n 1 value 4.0
# t 138 n 1 value 48.0
# t 139 n 1 value 10.0
# t 140 n 1 value 7.0
# t 141 n 1 value 3.0
# t 142 n 1 value 23.0
# t 143 n 1 value 9.0
# t 0 n 2 value 25.0
# t 1 n 2 value 43.0
# t 2 n 2 value 29.0
# t 3 n 2 value 36.0
# t 4 n 2 value 55.0
# t 5 n 2 value 14.0
# t 6 n 2 value 51.0
# t 7 n 2 value 15.0
# t 8 n 2 value 64.0
# t 9 n 2 value 24.0
# t 10 n 2 value 30.0
# t 11 n 2 value 113.0
# t 12 n 2 value 13.0
# t 13 n 2 value 21.0
# t 14 n 2 value 15.0
# t 15 n 2 value 54.0
# t 16 n 2 value 24.0
# t 17 n 2 value 13.0
# t 18 n 2 value 54.0
# t 19 n 2 value 10.0
# t 20 n 2 value 76.0
# t 21 n 2 value 18.0
# t 22 n 2 value 39.0
# t 23 n 2 value 15.0
# t 24 n 2 value 41.0
# t 25 n 2 value 26.0
# t 26 n 2 value 47.0
# t 27 n 2 value 17.0
# t 28 n 2 value 69.0
# t 29 n 2 value 3.0
# t 30 n 2 value 10.0
# t 31 n 2 value 17.0
# t 32 n 2 value 22.0
# t 33 n 2 value 23.0
# t 34 n 2 value 99.0
# t 35 n 2 value 10.0
# t 36 n 2 value 12.0
# t 37 n 2 value 16.0
# t 38 n 2 value 32.0
# t 39 n 2 value 8.0
# t 40 n 2 value 132.0
# t 41 n 2 value 20.0
# t 42 n 2 value 33.0
# t 43 n 2 value 65.0
# t 44 n 2 value 17.0
# t 45 n 2 value 29.0
# t 46 n 2 value 38.0
# t 47 n 2 value 14.0
# t 48 n 2 value 30.0
# t 49 n 2 value 56.0
# t 50 n 2 value 23.0
# t 51 n 2 value 9.0
# t 52 n 2 value 30.0
# t 53 n 2 value 13.0
# t 54 n 2 value 27.0
# t 55 n 2 value 26.0
# t 56 n 2 value 16.0
# t 57 n 2 value 106.0
# t 58 n 2 value 33.0
# t 59 n 2 value 63.0
# t 60 n 2 value 116.0
# t 61 n 2 value 11.0
# t 62 n 2 value 46.0
# t 63 n 2 value 15.0
# t 64 n 2 value 27.0
# t 65 n 2 value 44.0
# t 66 n 2 value 17.0
# t 67 n 2 value 24.0
# t 68 n 2 value 95.0
# t 69 n 2 value 28.0
# t 70 n 2 value 34.0
# t 71 n 2 value 34.0
# t 72 n 2 value 45.0
# t 73 n 2 value 33.0
# t 74 n 2 value 24.0
# t 75 n 2 value 57.0
# t 76 n 2 value 46.0
# t 77 n 2 value 112.0
# t 78 n 2 value 77.0
# t 79 n 2 value 31.0
# t 80 n 2 value 67.0
# t 81 n 2 value 28.0
# t 82 n 2 value 22.0
# t 83 n 2 value 20.0
# t 84 n 2 value 12.0
# t 85 n 2 value 12.0
# t 86 n 2 value 28.0
# t 87 n 2 value 12.0
# t 88 n 2 value 21.0
# t 89 n 2 value 27.0
# t 90 n 2 value 20.0
# t 91 n 2 value 49.0
# t 92 n 2 value 60.0
# t 93 n 2 value 71.0
# t 94 n 2 value 22.0
# t 95 n 2 value 15.0
# t 96 n 2 value 18.0
# t 97 n 2 value 29.0
# t 98 n 2 value 95.0
# t 99 n 2 value 21.0
# t 100 n 2 value 10.0
# t 101 n 2 value 45.0
# t 102 n 2 value 33.0
# t 103 n 2 value 20.0
# t 104 n 2 value 42.0
# t 105 n 2 value 46.0
# t 106 n 2 value 27.0
# t 107 n 2 value 20.0
# t 108 n 2 value 45.0
# t 109 n 2 value 44.0
# t 110 n 2 value 28.0
# t 111 n 2 value 47.0
# t 112 n 2 value 43.0
# t 113 n 2 value 19.0
# t 114 n 2 value 30.0
# t 115 n 2 value 27.0
# t 116 n 2 value 14.0
# t 117 n 2 value 17.0
# t 118 n 2 value 13.0
# t 119 n 2 value 12.0
# t 120 n 2 value 27.0
# t 121 n 2 value 118.0
# t 122 n 2 value 85.0
# t 123 n 2 value 43.0
# t 124 n 2 value 13.0
# t 125 n 2 value 29.0
# t 126 n 2 value 12.0
# t 127 n 2 value 14.0
# t 128 n 2 value 16.0
# t 129 n 2 value 98.0
# t 130 n 2 value 7.0
# t 131 n 2 value 5.0
# t 132 n 2 value 13.0
# t 133 n 2 value 17.0
# t 134 n 2 value 24.0
# t 135 n 2 value 17.0
# t 136 n 2 value 13.0
# t 137 n 2 value 23.0
# t 138 n 2 value 15.0
# t 139 n 2 value 41.0
# t 140 n 2 value 67.0
# t 141 n 2 value 29.0
# t 142 n 2 value 8.0
# t 143 n 2 value 18.0
# t 0 n 3 value 0.0
# t 1 n 3 value 31.0
# t 2 n 3 value 5.0
# t 3 n 3 value 6.0
# t 4 n 3 value 15.0
# t 5 n 3 value 1.0
# t 6 n 3 value 21.0
# t 7 n 3 value 0.0
# t 8 n 3 value 21.0
# t 9 n 3 value 5.0
# t 10 n 3 value 20.0
# t 11 n 3 value 8.0
# t 12 n 3 value 0.0
# t 13 n 3 value 3.0
# t 14 n 3 value 1.0
# t 15 n 3 value 0.0
# t 16 n 3 value 2.0
# t 17 n 3 value 0.0
# t 18 n 3 value 27.0
# t 19 n 3 value 6.0
# t 20 n 3 value 0.0
# t 21 n 3 value 1.0
# t 22 n 3 value 0.0
# t 23 n 3 value 1.0
# t 24 n 3 value 1.0
# t 25 n 3 value 61.0
# t 26 n 3 value 7.0
# t 27 n 3 value 1.0
# t 28 n 3 value 25.0
# t 29 n 3 value 0.0
# t 30 n 3 value 0.0
# t 31 n 3 value 1.0
# t 32 n 3 value 21.0
# t 33 n 3 value 24.0
# t 34 n 3 value 0.0
# t 35 n 3 value 0.0
# t 36 n 3 value 2.0
# t 37 n 3 value 0.0
# t 38 n 3 value 67.0
# t 39 n 3 value 1.0
# t 40 n 3 value 1.0
# t 41 n 3 value 2.0
# t 42 n 3 value 63.0
# t 43 n 3 value 21.0
# t 44 n 3 value 13.0
# t 45 n 3 value 1.0
# t 46 n 3 value 9.0
# t 47 n 3 value 2.0
# t 48 n 3 value 21.0
# t 49 n 3 value 0.0
# t 50 n 3 value 0.0
# t 51 n 3 value 0.0
# t 52 n 3 value 0.0
# t 53 n 3 value 5.0
# t 54 n 3 value 36.0
# t 55 n 3 value 0.0
# t 56 n 3 value 2.0
# t 57 n 3 value 1.0
# t 58 n 3 value 38.0
# t 59 n 3 value 3.0
# t 60 n 3 value 3.0
# t 61 n 3 value 2.0
# t 62 n 3 value 10.0
# t 63 n 3 value 1.0
# t 64 n 3 value 61.0
# t 65 n 3 value 3.0
# t 66 n 3 value 0.0
# t 67 n 3 value 40.0
# t 68 n 3 value 23.0
# t 69 n 3 value 5.0
# t 70 n 3 value 0.0
# t 71 n 3 value 11.0
# t 72 n 3 value 0.0
# t 73 n 3 value 24.0
# t 74 n 3 value 12.0
# t 75 n 3 value 6.0
# t 76 n 3 value 14.0
# t 77 n 3 value 0.0
# t 78 n 3 value 3.0
# t 79 n 3 value 49.0
# t 80 n 3 value 14.0
# t 81 n 3 value 7.0
# t 82 n 3 value 3.0
# t 83 n 3 value 30.0
# t 84 n 3 value 2.0
# t 85 n 3 value 71.0
# t 86 n 3 value 0.0
# t 87 n 3 value 0.0
# t 88 n 3 value 29.0
# t 89 n 3 value 11.0
# t 90 n 3 value 36.0
# t 91 n 3 value 3.0
# t 92 n 3 value 37.0
# t 93 n 3 value 0.0
# t 94 n 3 value 0.0
# t 95 n 3 value 8.0
# t 96 n 3 value 43.0
# t 97 n 3 value 30.0
# t 98 n 3 value 3.0
# t 99 n 3 value 3.0
# t 100 n 3 value 9.0
# t 101 n 3 value 28.0
# t 102 n 3 value 1.0
# t 103 n 3 value 3.0
# t 104 n 3 value 10.0
# t 105 n 3 value 10.0
# t 106 n 3 value 3.0
# t 107 n 3 value 4.0
# t 108 n 3 value 12.0
# t 109 n 3 value 5.0
# t 110 n 3 value 23.0
# t 111 n 3 value 6.0
# t 112 n 3 value 3.0
# t 113 n 3 value 10.0
# t 114 n 3 value 26.0
# t 115 n 3 value 26.0
# t 116 n 3 value 0.0
# t 117 n 3 value 5.0
# t 118 n 3 value 4.0
# t 119 n 3 value 35.0
# t 120 n 3 value 17.0
# t 121 n 3 value 4.0
# t 122 n 3 value 0.0
# t 123 n 3 value 30.0
# t 124 n 3 value 6.0
# t 125 n 3 value 2.0
# t 126 n 3 value 55.0
# t 127 n 3 value 6.0
# t 128 n 3 value 7.0
# t 129 n 3 value 6.0
# t 130 n 3 value 12.0
# t 131 n 3 value 0.0
# t 132 n 3 value 0.0
# t 133 n 3 value 23.0
# t 134 n 3 value 1.0
# t 135 n 3 value 2.0
# t 136 n 3 value 0.0
# t 137 n 3 value 39.0
# t 138 n 3 value 0.0
# t 139 n 3 value 3.0
# t 140 n 3 value 18.0
# t 141 n 3 value 3.0
# t 142 n 3 value 0.0
# t 143 n 3 value 0.0
# t 0 n 4 value 8.0
# t 1 n 4 value 5.0
# t 2 n 4 value 47.0
# t 3 n 4 value 16.0
# t 4 n 4 value 4.0
# t 5 n 4 value 8.0
# t 6 n 4 value 12.0
# t 7 n 4 value 3.0
# t 8 n 4 value 14.0
# t 9 n 4 value 16.0
# t 10 n 4 value 3.0
# t 11 n 4 value 35.0
# t 12 n 4 value 2.0
# t 13 n 4 value 29.0
# t 14 n 4 value 6.0
# t 15 n 4 value 40.0
# t 16 n 4 value 19.0
# t 17 n 4 value 2.0
# t 18 n 4 value 6.0
# t 19 n 4 value 3.0
# t 20 n 4 value 46.0
# t 21 n 4 value 18.0
# t 22 n 4 value 36.0
# t 23 n 4 value 2.0
# t 24 n 4 value 8.0
# t 25 n 4 value 12.0
# t 26 n 4 value 42.0
# t 27 n 4 value 23.0
# t 28 n 4 value 15.0
# t 29 n 4 value 6.0
# t 30 n 4 value 2.0
# t 31 n 4 value 34.0
# t 32 n 4 value 8.0
# t 33 n 4 value 16.0
# t 34 n 4 value 62.0
# t 35 n 4 value 32.0
# t 36 n 4 value 4.0
# t 37 n 4 value 12.0
# t 38 n 4 value 4.0
# t 39 n 4 value 7.0
# t 40 n 4 value 69.0
# t 41 n 4 value 2.0
# t 42 n 4 value 26.0
# t 43 n 4 value 25.0
# t 44 n 4 value 15.0
# t 45 n 4 value 51.0
# t 46 n 4 value 44.0
# t 47 n 4 value 26.0
# t 48 n 4 value 23.0
# t 49 n 4 value 62.0
# t 50 n 4 value 5.0
# t 51 n 4 value 1.0
# t 52 n 4 value 47.0
# t 53 n 4 value 4.0
# t 54 n 4 value 12.0
# t 55 n 4 value 27.0
# t 56 n 4 value 6.0
# t 57 n 4 value 58.0
# t 58 n 4 value 15.0
# t 59 n 4 value 47.0
# t 60 n 4 value 75.0
# t 61 n 4 value 43.0
# t 62 n 4 value 17.0
# t 63 n 4 value 8.0
# t 64 n 4 value 24.0
# t 65 n 4 value 42.0
# t 66 n 4 value 5.0
# t 67 n 4 value 19.0
# t 68 n 4 value 32.0
# t 69 n 4 value 25.0
# t 70 n 4 value 6.0
# t 71 n 4 value 23.0
# t 72 n 4 value 35.0
# t 73 n 4 value 31.0
# t 74 n 4 value 19.0
# t 75 n 4 value 19.0
# t 76 n 4 value 54.0
# t 77 n 4 value 64.0
# t 78 n 4 value 62.0
# t 79 n 4 value 21.0
# t 80 n 4 value 21.0
# t 81 n 4 value 18.0
# t 82 n 4 value 19.0
# t 83 n 4 value 26.0
# t 84 n 4 value 12.0
# t 85 n 4 value 29.0
# t 86 n 4 value 43.0
# t 87 n 4 value 2.0
# t 88 n 4 value 11.0
# t 89 n 4 value 21.0
# t 90 n 4 value 15.0
# t 91 n 4 value 64.0
# t 92 n 4 value 36.0
# t 93 n 4 value 47.0
# t 94 n 4 value 16.0
# t 95 n 4 value 8.0
# t 96 n 4 value 8.0
# t 97 n 4 value 13.0
# t 98 n 4 value 71.0
# t 99 n 4 value 29.0
# t 100 n 4 value 8.0
# t 101 n 4 value 8.0
# t 102 n 4 value 32.0
# t 103 n 4 value 11.0
# t 104 n 4 value 35.0
# t 105 n 4 value 45.0
# t 106 n 4 value 7.0
# t 107 n 4 value 10.0
# t 108 n 4 value 46.0
# t 109 n 4 value 4.0
# t 110 n 4 value 37.0
# t 111 n 4 value 11.0
# t 112 n 4 value 9.0
# t 113 n 4 value 14.0
# t 114 n 4 value 10.0
# t 115 n 4 value 50.0
# t 116 n 4 value 20.0
# t 117 n 4 value 24.0
# t 118 n 4 value 33.0
# t 119 n 4 value 20.0
# t 120 n 4 value 21.0
# t 121 n 4 value 65.0
# t 122 n 4 value 62.0
# t 123 n 4 value 15.0
# t 124 n 4 value 34.0
# t 125 n 4 value 16.0
# t 126 n 4 value 14.0
# t 127 n 4 value 12.0
# t 128 n 4 value 6.0
# t 129 n 4 value 59.0
# t 130 n 4 value 31.0
# t 131 n 4 value 1.0
# t 132 n 4 value 5.0
# t 133 n 4 value 8.0
# t 134 n 4 value 22.0
# t 135 n 4 value 28.0
# t 136 n 4 value 10.0
# t 137 n 4 value 12.0
# t 138 n 4 value 7.0
# t 139 n 4 value 32.0
# t 140 n 4 value 38.0
# t 141 n 4 value 16.0
# t 142 n 4 value 10.0
# t 143 n 4 value 11.0
# t 0 n 5 value 47.0
# t 1 n 5 value 33.0
# t 2 n 5 value 28.0
# t 3 n 5 value 2.0
# t 4 n 5 value 40.0
# t 5 n 5 value 25.0
# t 6 n 5 value 10.0
# t 7 n 5 value 43.0
# t 8 n 5 value 16.0
# t 9 n 5 value 13.0
# t 10 n 5 value 6.0
# t 11 n 5 value 8.0
# t 12 n 5 value 75.0
# t 13 n 5 value 9.0
# t 14 n 5 value 47.0
# t 15 n 5 value 12.0
# t 16 n 5 value 22.0
# t 17 n 5 value 78.0
# t 18 n 5 value 16.0
# t 19 n 5 value 69.0
# t 20 n 5 value 8.0
# t 21 n 5 value 27.0
# t 22 n 5 value 28.0
# t 23 n 5 value 73.0
# t 24 n 5 value 32.0
# t 25 n 5 value 19.0
# t 26 n 5 value 7.0
# t 27 n 5 value 30.0
# t 28 n 5 value 10.0
# t 29 n 5 value 34.0
# t 30 n 5 value 73.0
# t 31 n 5 value 18.0
# t 32 n 5 value 42.0
# t 33 n 5 value 3.0
# t 34 n 5 value 13.0
# t 35 n 5 value 4.0
# t 36 n 5 value 27.0
# t 37 n 5 value 30.0
# t 38 n 5 value 18.0
# t 39 n 5 value 66.0
# t 40 n 5 value 4.0
# t 41 n 5 value 75.0
# t 42 n 5 value 9.0
# t 43 n 5 value 4.0
# t 44 n 5 value 14.0
# t 45 n 5 value 16.0
# t 46 n 5 value 10.0
# t 47 n 5 value 14.0
# t 48 n 5 value 33.0
# t 49 n 5 value 3.0
# t 50 n 5 value 41.0
# t 51 n 5 value 104.0
# t 52 n 5 value 17.0
# t 53 n 5 value 18.0
# t 54 n 5 value 7.0
# t 55 n 5 value 24.0
# t 56 n 5 value 80.0
# t 57 n 5 value 6.0
# t 58 n 5 value 10.0
# t 59 n 5 value 80.0
# t 60 n 5 value 5.0
# t 61 n 5 value 4.0
# t 62 n 5 value 15.0
# t 63 n 5 value 13.0
# t 64 n 5 value 22.0
# t 65 n 5 value 18.0
# t 66 n 5 value 125.0
# t 67 n 5 value 43.0
# t 68 n 5 value 4.0
# t 69 n 5 value 35.0
# t 70 n 5 value 34.0
# t 71 n 5 value 5.0
# t 72 n 5 value 13.0
# t 73 n 5 value 34.0
# t 74 n 5 value 121.0
# t 75 n 5 value 17.0
# t 76 n 5 value 24.0
# t 77 n 5 value 3.0
# t 78 n 5 value 4.0
# t 79 n 5 value 13.0
# t 80 n 5 value 8.0
# t 81 n 5 value 4.0
# t 82 n 5 value 14.0
# t 83 n 5 value 15.0
# t 84 n 5 value 50.0
# t 85 n 5 value 29.0
# t 86 n 5 value 1.0
# t 87 n 5 value 133.0
# t 88 n 5 value 39.0
# t 89 n 5 value 74.0
# t 90 n 5 value 38.0
# t 91 n 5 value 28.0
# t 92 n 5 value 5.0
# t 93 n 5 value 5.0
# t 94 n 5 value 67.0
# t 95 n 5 value 72.0
# t 96 n 5 value 11.0
# t 97 n 5 value 5.0
# t 98 n 5 value 6.0
# t 99 n 5 value 35.0
# t 100 n 5 value 28.0
# t 101 n 5 value 7.0
# t 102 n 5 value 6.0
# t 103 n 5 value 133.0
# t 104 n 5 value 10.0
# t 105 n 5 value 2.0
# t 106 n 5 value 51.0
# t 107 n 5 value 22.0
# t 108 n 5 value 4.0
# t 109 n 5 value 51.0
# t 110 n 5 value 3.0
# t 111 n 5 value 23.0
# t 112 n 5 value 33.0
# t 113 n 5 value 109.0
# t 114 n 5 value 39.0
# t 115 n 5 value 7.0
# t 116 n 5 value 6.0
# t 117 n 5 value 30.0
# t 118 n 5 value 62.0
# t 119 n 5 value 14.0
# t 120 n 5 value 2.0
# t 121 n 5 value 7.0
# t 122 n 5 value 0.0
# t 123 n 5 value 2.0
# t 124 n 5 value 80.0
# t 125 n 5 value 19.0
# t 126 n 5 value 6.0
# t 127 n 5 value 1.0
# t 128 n 5 value 45.0
# t 129 n 5 value 1.0
# t 130 n 5 value 34.0
# t 131 n 5 value 28.0
# t 132 n 5 value 35.0
# t 133 n 5 value 2.0
# t 134 n 5 value 17.0
# t 135 n 5 value 1.0
# t 136 n 5 value 5.0
# t 137 n 5 value 5.0
# t 138 n 5 value 6.0
# t 139 n 5 value 7.0
# t 140 n 5 value 0.0
# t 141 n 5 value 2.0
# t 142 n 5 value 77.0
# t 143 n 5 value 2.0
# t 0 n 6 value 45.0
# t 1 n 6 value 55.0
# t 2 n 6 value 65.0
# t 3 n 6 value 44.0
# t 4 n 6 value 66.0
# t 5 n 6 value 44.0
# t 6 n 6 value 37.0
# t 7 n 6 value 48.0
# t 8 n 6 value 47.0
# t 9 n 6 value 52.0
# t 10 n 6 value 56.0
# t 11 n 6 value 35.0
# t 12 n 6 value 64.0
# t 13 n 6 value 45.0
# t 14 n 6 value 67.0
# t 15 n 6 value 39.0
# t 16 n 6 value 37.0
# t 17 n 6 value 50.0
# t 18 n 6 value 93.0
# t 19 n 6 value 52.0
# t 20 n 6 value 39.0
# t 21 n 6 value 70.0
# t 22 n 6 value 58.0
# t 23 n 6 value 70.0
# t 24 n 6 value 110.0
# t 25 n 6 value 81.0
# t 26 n 6 value 65.0
# t 27 n 6 value 138.0
# t 28 n 6 value 78.0
# t 29 n 6 value 98.0
# t 30 n 6 value 74.0
# t 31 n 6 value 107.0
# t 32 n 6 value 88.0
# t 33 n 6 value 73.0
# t 34 n 6 value 57.0
# t 35 n 6 value 68.0
# t 36 n 6 value 95.0
# t 37 n 6 value 135.0
# t 38 n 6 value 78.0
# t 39 n 6 value 78.0
# t 40 n 6 value 82.0
# t 41 n 6 value 114.0
# t 42 n 6 value 88.0
# t 43 n 6 value 72.0
# t 44 n 6 value 118.0
# t 45 n 6 value 113.0
# t 46 n 6 value 101.0
# t 47 n 6 value 118.0
# t 48 n 6 value 117.0
# t 49 n 6 value 87.0
# t 50 n 6 value 142.0
# t 51 n 6 value 99.0
# t 52 n 6 value 80.0
# t 53 n 6 value 121.0
# t 54 n 6 value 100.0
# t 55 n 6 value 137.0
# t 56 n 6 value 97.0
# t 57 n 6 value 72.0
# t 58 n 6 value 89.0
# t 59 n 6 value 65.0
# t 60 n 6 value 65.0
# t 61 n 6 value 86.0
# t 62 n 6 value 102.0
# t 63 n 6 value 81.0
# t 64 n 6 value 70.0
# t 65 n 6 value 64.0
# t 66 n 6 value 81.0
# t 67 n 6 value 107.0
# t 68 n 6 value 78.0
# t 69 n 6 value 137.0
# t 70 n 6 value 126.0
# t 71 n 6 value 51.0
# t 72 n 6 value 83.0
# t 73 n 6 value 94.0
# t 74 n 6 value 73.0
# t 75 n 6 value 134.0
# t 76 n 6 value 120.0
# t 77 n 6 value 59.0
# t 78 n 6 value 88.0
# t 79 n 6 value 93.0
# t 80 n 6 value 68.0
# t 81 n 6 value 87.0
# t 82 n 6 value 105.0
# t 83 n 6 value 104.0
# t 84 n 6 value 149.0
# t 85 n 6 value 84.0
# t 86 n 6 value 96.0
# t 87 n 6 value 100.0
# t 88 n 6 value 99.0
# t 89 n 6 value 127.0
# t 90 n 6 value 113.0
# t 91 n 6 value 71.0
# t 92 n 6 value 90.0
# t 93 n 6 value 51.0
# t 94 n 6 value 75.0
# t 95 n 6 value 111.0
# t 96 n 6 value 108.0
# t 97 n 6 value 84.0
# t 98 n 6 value 62.0
# t 99 n 6 value 164.0
# t 100 n 6 value 128.0
# t 101 n 6 value 117.0
# t 102 n 6 value 87.0
# t 103 n 6 value 106.0
# t 104 n 6 value 83.0
# t 105 n 6 value 66.0
# t 106 n 6 value 140.0
# t 107 n 6 value 72.0
# t 108 n 6 value 58.0
# t 109 n 6 value 107.0
# t 110 n 6 value 70.0
# t 111 n 6 value 95.0
# t 112 n 6 value 107.0
# t 113 n 6 value 86.0
# t 114 n 6 value 109.0
# t 115 n 6 value 126.0
# t 116 n 6 value 82.0
# t 117 n 6 value 87.0
# t 118 n 6 value 40.0
# t 119 n 6 value 46.0
# t 120 n 6 value 46.0
# t 121 n 6 value 38.0
# t 122 n 6 value 30.0
# t 123 n 6 value 45.0
# t 124 n 6 value 41.0
# t 125 n 6 value 20.0
# t 126 n 6 value 41.0
# t 127 n 6 value 37.0
# t 128 n 6 value 54.0
# t 129 n 6 value 24.0
# t 130 n 6 value 34.0
# t 131 n 6 value 70.0
# t 132 n 6 value 52.0
# t 133 n 6 value 44.0
# t 134 n 6 value 43.0
# t 135 n 6 value 20.0
# t 136 n 6 value 51.0
# t 137 n 6 value 37.0
# t 138 n 6 value 52.0
# t 139 n 6 value 31.0
# t 140 n 6 value 46.0
# t 141 n 6 value 46.0
# t 142 n 6 value 46.0
# t 143 n 6 value 67.0
# t 0 n 7 value 1.0
# t 1 n 7 value 1.0
# t 2 n 7 value 2.0
# t 3 n 7 value 0.0
# t 4 n 7 value 0.0
# t 5 n 7 value 4.0
# t 6 n 7 value 1.0
# t 7 n 7 value 11.0
# t 8 n 7 value 0.0
# t 9 n 7 value 7.0
# t 10 n 7 value 1.0
# t 11 n 7 value 1.0
# t 12 n 7 value 1.0
# t 13 n 7 value 1.0
# t 14 n 7 value 10.0
# t 15 n 7 value 0.0
# t 16 n 7 value 1.0
# t 17 n 7 value 1.0
# t 18 n 7 value 1.0
# t 19 n 7 value 2.0
# t 20 n 7 value 2.0
# t 21 n 7 value 4.0
# t 22 n 7 value 2.0
# t 23 n 7 value 0.0
# t 24 n 7 value 25.0
# t 25 n 7 value 0.0
# t 26 n 7 value 0.0
# t 27 n 7 value 11.0
# t 28 n 7 value 0.0
# t 29 n 7 value 13.0
# t 30 n 7 value 3.0
# t 31 n 7 value 4.0
# t 32 n 7 value 0.0
# t 33 n 7 value 1.0
# t 34 n 7 value 0.0
# t 35 n 7 value 1.0
# t 36 n 7 value 4.0
# t 37 n 7 value 14.0
# t 38 n 7 value 0.0
# t 39 n 7 value 5.0
# t 40 n 7 value 0.0
# t 41 n 7 value 0.0
# t 42 n 7 value 1.0
# t 43 n 7 value 0.0
# t 44 n 7 value 1.0
# t 45 n 7 value 0.0
# t 46 n 7 value 0.0
# t 47 n 7 value 7.0
# t 48 n 7 value 1.0
# t 49 n 7 value 2.0
# t 50 n 7 value 14.0
# t 51 n 7 value 7.0
# t 52 n 7 value 1.0
# t 53 n 7 value 5.0
# t 54 n 7 value 0.0
# t 55 n 7 value 20.0
# t 56 n 7 value 0.0
# t 57 n 7 value 3.0
# t 58 n 7 value 3.0
# t 59 n 7 value 5.0
# t 60 n 7 value 0.0
# t 61 n 7 value 1.0
# t 62 n 7 value 14.0
# t 63 n 7 value 8.0
# t 64 n 7 value 3.0
# t 65 n 7 value 0.0
# t 66 n 7 value 2.0
# t 67 n 7 value 4.0
# t 68 n 7 value 3.0
# t 69 n 7 value 22.0
# t 70 n 7 value 15.0
# t 71 n 7 value 0.0
# t 72 n 7 value 0.0
# t 73 n 7 value 24.0
# t 74 n 7 value 3.0
# t 75 n 7 value 8.0
# t 76 n 7 value 18.0
# t 77 n 7 value 3.0
# t 78 n 7 value 1.0
# t 79 n 7 value 1.0
# t 80 n 7 value 0.0
# t 81 n 7 value 0.0
# t 82 n 7 value 12.0
# t 83 n 7 value 3.0
# t 84 n 7 value 19.0
# t 85 n 7 value 0.0
# t 86 n 7 value 2.0
# t 87 n 7 value 11.0
# t 88 n 7 value 3.0
# t 89 n 7 value 6.0
# t 90 n 7 value 0.0
# t 91 n 7 value 2.0
# t 92 n 7 value 0.0
# t 93 n 7 value 0.0
# t 94 n 7 value 7.0
# t 95 n 7 value 2.0
# t 96 n 7 value 1.0
# t 97 n 7 value 0.0
# t 98 n 7 value 3.0
# t 99 n 7 value 12.0
# t 100 n 7 value 11.0
# t 101 n 7 value 0.0
# t 102 n 7 value 2.0
# t 103 n 7 value 7.0
# t 104 n 7 value 14.0
# t 105 n 7 value 0.0
# t 106 n 7 value 20.0
# t 107 n 7 value 35.0
# t 108 n 7 value 0.0
# t 109 n 7 value 13.0
# t 110 n 7 value 16.0
# t 111 n 7 value 11.0
# t 112 n 7 value 17.0
# t 113 n 7 value 4.0
# t 114 n 7 value 0.0
# t 115 n 7 value 2.0
# t 116 n 7 value 0.0
# t 117 n 7 value 4.0
# t 118 n 7 value 2.0
# t 119 n 7 value 0.0
# t 120 n 7 value 0.0
# t 121 n 7 value 1.0
# t 122 n 7 value 0.0
# t 123 n 7 value 0.0
# t 124 n 7 value 0.0
# t 125 n 7 value 0.0
# t 126 n 7 value 2.0
# t 127 n 7 value 16.0
# t 128 n 7 value 9.0
# t 129 n 7 value 0.0
# t 130 n 7 value 2.0
# t 131 n 7 value 13.0
# t 132 n 7 value 2.0
# t 133 n 7 value 4.0
# t 134 n 7 value 13.0
# t 135 n 7 value 1.0
# t 136 n 7 value 3.0
# t 137 n 7 value 0.0
# t 138 n 7 value 12.0
# t 139 n 7 value 0.0
# t 140 n 7 value 2.0
# t 141 n 7 value 0.0
# t 142 n 7 value 5.0
# t 143 n 7 value 4.0
# t 0 n 8 value 34.0
# t 1 n 8 value 41.0
# t 2 n 8 value 0.0
# t 3 n 8 value 1.0
# t 4 n 8 value 2.0
# t 5 n 8 value 4.0
# t 6 n 8 value 2.0
# t 7 n 8 value 1.0
# t 8 n 8 value 4.0
# t 9 n 8 value 9.0
# t 10 n 8 value 8.0
# t 11 n 8 value 5.0
# t 12 n 8 value 7.0
# t 13 n 8 value 6.0
# t 14 n 8 value 13.0
# t 15 n 8 value 31.0
# t 16 n 8 value 17.0
# t 17 n 8 value 20.0
# t 18 n 8 value 9.0
# t 19 n 8 value 23.0
# t 20 n 8 value 22.0
# t 21 n 8 value 10.0
# t 22 n 8 value 16.0
# t 23 n 8 value 3.0
# t 24 n 8 value 11.0
# t 25 n 8 value 0.0
# t 26 n 8 value 14.0
# t 27 n 8 value 10.0
# t 28 n 8 value 1.0
# t 29 n 8 value 10.0
# t 30 n 8 value 8.0
# t 31 n 8 value 5.0
# t 32 n 8 value 0.0
# t 33 n 8 value 4.0
# t 34 n 8 value 2.0
# t 35 n 8 value 3.0
# t 36 n 8 value 6.0
# t 37 n 8 value 6.0
# t 38 n 8 value 0.0
# t 39 n 8 value 16.0
# t 40 n 8 value 28.0
# t 41 n 8 value 4.0
# t 42 n 8 value 28.0
# t 43 n 8 value 6.0
# t 44 n 8 value 7.0
# t 45 n 8 value 20.0
# t 46 n 8 value 10.0
# t 47 n 8 value 36.0
# t 48 n 8 value 5.0
# t 49 n 8 value 22.0
# t 50 n 8 value 18.0
# t 51 n 8 value 18.0
# t 52 n 8 value 34.0
# t 53 n 8 value 22.0
# t 54 n 8 value 0.0
# t 55 n 8 value 6.0
# t 56 n 8 value 5.0
# t 57 n 8 value 22.0
# t 58 n 8 value 4.0
# t 59 n 8 value 28.0
# t 60 n 8 value 22.0
# t 61 n 8 value 13.0
# t 62 n 8 value 11.0
# t 63 n 8 value 27.0
# t 64 n 8 value 1.0
# t 65 n 8 value 22.0
# t 66 n 8 value 11.0
# t 67 n 8 value 6.0
# t 68 n 8 value 12.0
# t 69 n 8 value 9.0
# t 70 n 8 value 10.0
# t 71 n 8 value 3.0
# t 72 n 8 value 2.0
# t 73 n 8 value 29.0
# t 74 n 8 value 30.0
# t 75 n 8 value 5.0
# t 76 n 8 value 18.0
# t 77 n 8 value 2.0
# t 78 n 8 value 17.0
# t 79 n 8 value 11.0
# t 80 n 8 value 19.0
# t 81 n 8 value 10.0
# t 82 n 8 value 26.0
# t 83 n 8 value 1.0
# t 84 n 8 value 26.0
# t 85 n 8 value 0.0
# t 86 n 8 value 7.0
# t 87 n 8 value 18.0
# t 88 n 8 value 0.0
# t 89 n 8 value 6.0
# t 90 n 8 value 2.0
# t 91 n 8 value 15.0
# t 92 n 8 value 0.0
# t 93 n 8 value 2.0
# t 94 n 8 value 24.0
# t 95 n 8 value 8.0
# t 96 n 8 value 0.0
# t 97 n 8 value 0.0
# t 98 n 8 value 2.0
# t 99 n 8 value 12.0
# t 100 n 8 value 5.0
# t 101 n 8 value 0.0
# t 102 n 8 value 0.0
# t 103 n 8 value 13.0
# t 104 n 8 value 13.0
# t 105 n 8 value 1.0
# t 106 n 8 value 11.0
# t 107 n 8 value 18.0
# t 108 n 8 value 1.0
# t 109 n 8 value 10.0
# t 110 n 8 value 13.0
# t 111 n 8 value 0.0
# t 112 n 8 value 8.0
# t 113 n 8 value 1.0
# t 114 n 8 value 1.0
# t 115 n 8 value 5.0
# t 116 n 8 value 7.0
# t 117 n 8 value 23.0
# t 118 n 8 value 25.0
# t 119 n 8 value 0.0
# t 120 n 8 value 1.0
# t 121 n 8 value 0.0
# t 122 n 8 value 0.0
# t 123 n 8 value 0.0
# t 124 n 8 value 15.0
# t 125 n 8 value 12.0
# t 126 n 8 value 1.0
# t 127 n 8 value 17.0
# t 128 n 8 value 5.0
# t 129 n 8 value 35.0
# t 130 n 8 value 2.0
# t 131 n 8 value 8.0
# t 132 n 8 value 16.0
# t 133 n 8 value 9.0
# t 134 n 8 value 4.0
# t 135 n 8 value 5.0
# t 136 n 8 value 4.0
# t 137 n 8 value 5.0
# t 138 n 8 value 35.0
# t 139 n 8 value 11.0
# t 140 n 8 value 0.0
# t 141 n 8 value 33.0
# t 142 n 8 value 24.0
# t 143 n 8 value 61.0
# t 0 n 9 value 54.0
# t 1 n 9 value 153.0
# t 2 n 9 value 56.0
# t 3 n 9 value 50.0
# t 4 n 9 value 85.0
# t 5 n 9 value 14.0
# t 6 n 9 value 179.0
# t 7 n 9 value 23.0
# t 8 n 9 value 135.0
# t 9 n 9 value 28.0
# t 10 n 9 value 126.0
# t 11 n 9 value 57.0
# t 12 n 9 value 30.0
# t 13 n 9 value 14.0
# t 14 n 9 value 13.0
# t 15 n 9 value 28.0
# t 16 n 9 value 22.0
# t 17 n 9 value 19.0
# t 18 n 9 value 224.0
# t 19 n 9 value 4.0
# t 20 n 9 value 12.0
# t 21 n 9 value 3.0
# t 22 n 9 value 13.0
# t 23 n 9 value 49.0
# t 24 n 9 value 24.0
# t 25 n 9 value 236.0
# t 26 n 9 value 93.0
# t 27 n 9 value 69.0
# t 28 n 9 value 179.0
# t 29 n 9 value 5.0
# t 30 n 9 value 23.0
# t 31 n 9 value 89.0
# t 32 n 9 value 156.0
# t 33 n 9 value 207.0
# t 34 n 9 value 55.0
# t 35 n 9 value 18.0
# t 36 n 9 value 62.0
# t 37 n 9 value 27.0
# t 38 n 9 value 216.0
# t 39 n 9 value 8.0
# t 40 n 9 value 73.0
# t 41 n 9 value 41.0
# t 42 n 9 value 238.0
# t 43 n 9 value 158.0
# t 44 n 9 value 171.0
# t 45 n 9 value 24.0
# t 46 n 9 value 101.0
# t 47 n 9 value 8.0
# t 48 n 9 value 162.0
# t 49 n 9 value 16.0
# t 50 n 9 value 11.0
# t 51 n 9 value 16.0
# t 52 n 9 value 6.0
# t 53 n 9 value 10.0
# t 54 n 9 value 273.0
# t 55 n 9 value 23.0
# t 56 n 9 value 46.0
# t 57 n 9 value 16.0
# t 58 n 9 value 179.0
# t 59 n 9 value 5.0
# t 60 n 9 value 86.0
# t 61 n 9 value 17.0
# t 62 n 9 value 135.0
# t 63 n 9 value 15.0
# t 64 n 9 value 236.0
# t 65 n 9 value 10.0
# t 66 n 9 value 10.0
# t 67 n 9 value 167.0
# t 68 n 9 value 237.0
# t 69 n 9 value 18.0
# t 70 n 9 value 9.0
# t 71 n 9 value 53.0
# t 72 n 9 value 13.0
# t 73 n 9 value 29.0
# t 74 n 9 value 18.0
# t 75 n 9 value 184.0
# t 76 n 9 value 96.0
# t 77 n 9 value 59.0
# t 78 n 9 value 44.0
# t 79 n 9 value 259.0
# t 80 n 9 value 230.0
# t 81 n 9 value 100.0
# t 82 n 9 value 14.0
# t 83 n 9 value 182.0
# t 84 n 9 value 14.0
# t 85 n 9 value 213.0
# t 86 n 9 value 24.0
# t 87 n 9 value 19.0
# t 88 n 9 value 138.0
# t 89 n 9 value 59.0
# t 90 n 9 value 131.0
# t 91 n 9 value 11.0
# t 92 n 9 value 152.0
# t 93 n 9 value 12.0
# t 94 n 9 value 3.0
# t 95 n 9 value 50.0
# t 96 n 9 value 233.0
# t 97 n 9 value 196.0
# t 98 n 9 value 67.0
# t 99 n 9 value 42.0
# t 100 n 9 value 87.0
# t 101 n 9 value 183.0
# t 102 n 9 value 14.0
# t 103 n 9 value 10.0
# t 104 n 9 value 9.0
# t 105 n 9 value 53.0
# t 106 n 9 value 20.0
# t 107 n 9 value 4.0
# t 108 n 9 value 87.0
# t 109 n 9 value 16.0
# t 110 n 9 value 19.0
# t 111 n 9 value 159.0
# t 112 n 9 value 40.0
# t 113 n 9 value 37.0
# t 114 n 9 value 178.0
# t 115 n 9 value 192.0
# t 116 n 9 value 16.0
# t 117 n 9 value 6.0
# t 118 n 9 value 18.0
# t 119 n 9 value 172.0
# t 120 n 9 value 124.0
# t 121 n 9 value 29.0
# t 122 n 9 value 4.0
# t 123 n 9 value 95.0
# t 124 n 9 value 6.0
# t 125 n 9 value 7.0
# t 126 n 9 value 146.0
# t 127 n 9 value 8.0
# t 128 n 9 value 15.0
# t 129 n 9 value 39.0
# t 130 n 9 value 56.0
# t 131 n 9 value 10.0
# t 132 n 9 value 4.0
# t 133 n 9 value 165.0
# t 134 n 9 value 15.0
# t 135 n 9 value 5.0
# t 136 n 9 value 65.0
# t 137 n 9 value 142.0
# t 138 n 9 value 12.0
# t 139 n 9 value 6.0
# t 140 n 9 value 163.0
# t 141 n 9 value 24.0
# t 142 n 9 value 3.0
# t 143 n 9 value 13.0
# [[ 16.   4.  25. ...   1.  34.  54.]
#  [  8.   1.  43. ...   1.  41. 153.]
#  [ 13.  29.  29. ...   2.   0.  56.]
#  ...
#  [ 13.   3.  29. ...   0.  33.  24.]
#  [ 18.  23.   8. ...   5.  24.   3.]
#  [ 19.   9.  18. ...   4.  61.  13.]]

# %%
# Calculate the tuning curve for each neuron

directions = np.unique(stim_direction) # find the different stimulus direction values
num_neurons = spike_counts.shape[1]

tuning_curves = np.zeros((len(directions), num_neurons)) # matrix of average counts per direction for each neuron
for i, d in enumerate(directions):
    for n in range(num_neurons):
        trials_for_direction_d = np.argwhere(stim_direction==d)
        tuning_curves[i, n] =  np.mean(spike_counts[n]) # Fill this in with the command to calculate the mean 
        # (i.e., np.mean()) of the rows specified by trials_for_direction_d in the
        # n'th column of the spike_counts matrix
# Out:
# 10

# %%
fig, axes = plt.subplots(4,3,figsize=(12,12),squeeze=False,sharex=True,sharey=True)
axis_list = axes.flatten()

for ax in axis_list:
    ax.set_axis_off()

for n in range(num_neurons):
    ax = axis_list[n]
    ax.set_axis_on()
    ax.plot(directions, tuning_curves[:,n],label='Neuron {}'.format(n))
    ax.set_ylabel('Average Spike Counts')
    ax.legend()
    ax.set_xlabel('Orientation Angle')
