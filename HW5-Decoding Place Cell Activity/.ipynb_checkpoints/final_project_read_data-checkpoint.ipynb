# %% [markdown]
# ## 1. Check installed Python packages

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.4
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# asttokens                          2.0.5
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# bokeh                              2.3.2
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              4.10.3
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# debugpy                            1.6.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# dill                               0.3.6
# distributed                        2021.4.0
# docutils                           0.17
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# executing                          0.8.3
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# gevent                             21.1.2
# glob2                              0.7
# gmpy2                              2.0.8
# greenlet                           1.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# interchange                        2021.0.4
# intervaltree                       3.1.0
# ipykernel                          6.13.1
# ipython                            8.4.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# matplotlib-inline                  0.1.3
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# monotonic                          1.6
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nelpy                              0.2.2
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# pansi                              2020.7.3
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                22.0.3
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# pure-eval                          0.2.2
# py                                 1.10.0
# py2neo                             2021.2.3
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# rope                               0.18.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.9.3
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# six                                1.15.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# stack-data                         0.2.0
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2020.10.1
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.2.2.post1
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wurlitzer                          2.1.0
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0
# WARNING: You are using pip version 22.0.3; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/jian/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## 2. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

import nelpy as nel # https://github.com/nelpy/nelpy (pip through github link)
import pandas as pd
import scipy.ndimage.filters # Need to update through pip install --upgrade
import os
import sys
import warnings
import numpy as np
import pickle
import random

import copy
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Load Data

# %%
jar = nel.load_pkl('final_project_data.nel') # we load the spike and position data

# %%
jar
# Out:
# {'metadata': {'source': 'gor01vvp01pin01_processed_speed.nel',
#   'session': '16-40-19',
#   'data_names': ['pos1d', 'spikes']},
#  'pos': <AnalogSignalArray at 0x7fdbc9662250: 1 signals (2 segments)> for a total of 41:50 minutes,
#  'spikes': <SpikeTrainArray at 0x7fdbc9662190: 117 units (2 segments)> at 32552 Hz from 2006-6-07_16-40-19}

# %%
spikes = jar['spikes'].bin(ds=.1)
spikes.data.shape
# Out:
# (117, 25099)

# %%
spikes.n_events
# Out:
# array([ 27573,    436,  81908,    563,    419,   3139,    269,   7998,
#           603,   5341,   3922,  36055,   2118,   2209,   1667,    219,
#         38562,    180,    169,    564,  64219,   3064,   1361,   4210,
#           276,   1286,     84,   5961,    240,   1883,     39,    693,
#             3,   2617,    765,  20330,   2243,    148,    397,    202,
#           932,   6953,   2295,   1302,    139,   5086,    357,    184,
#          1048,   2068,     34,  16016,   3209,  86110,   1017,   2862,
#          4455,  26662,   7413,  18152,   1020,  19094,  27126,   5016,
#          5207,    132,   2296, 100992,    726,   2143,   1345,   3975,
#            86,   2996,  70500,    409,   1280,    353,    583,     89,
#           336,   1320,   4224,    374,     15,   3060,    141,    483,
#           364,   3227,    518,     67,   1231,   1730,   5434,      6,
#           947,    258,  60302,  17321,    725,    136,   9796,   1030,
#          5032,   1791,  89523,    227,  11488,   2310,   2526,    606,
#          1095,   2046,   1802,   1149,   8852])

# %%
pos = jar['pos']
plt.plot(pos.data.squeeze())
plt.title('Full Data Including Long and Short Track Periods')
# Out:
# Text(0.5, 1.0, 'Full Data Including Long and Short Track Periods')

# %%
# Get data only for long track portion of experiment
print('Nelpy epochs in data\n', pos.support.time) #For the position data, the different sleep, run epochs define a 7 member EpochArray, which can be accessed using pos.support.

long_track_pos = pos[[0],:] # nelpy indexing by first set of data
long_track_spikes = spikes[[0],:]
tvals, vals = long_track_pos.asarray() # Access timestamps and channel data as numpy arrays
fig, ax = plt.subplots(1,1,figsize=(12,3))
ax.plot(tvals, vals)
ax.set_title('Initial Long Track Segment')
# Out:
# WARNING:root:ignoring signal outside of support
# WARNING:root:ignoring events outside of eventarray support
# Nelpy epochs in data
#  [[   0 1180]
#  [1250 2580]]
# Text(0.5, 1.0, 'Initial Long Track Segment')

# %%
# Can we use speed to find the lap boundaries?

# Calculate the speed by taking the derivative of the position
sigma_500ms = 0.5
speed = nel.utils.ddt_asa(long_track_pos, smooth=True, sigma=sigma_500ms)
tvals, vals = speed.asarray()
plt.plot(tvals, vals)

# %%
# get_run_epochs is a utility function which wraps a speed threshold. This finds periods where the speed
#   is greater than v2 and reaches at least a maximum of v1.
run_epochs = nel.utils.get_run_epochs(speed, v1=35, v2=3) # original choice
print((run_epochs.time.shape[0]))
print(run_epochs.time)

# This looks about right - there seem to be 19.5 full laps, which would be 39 half laps
# and we find 40 epochs.
# Out:
# 40
# [[   7.76666667   20.33333333]
#  [  29.33333333   35.06666667]
#  [  49.35         63.9       ]
#  [ 166.86666667  183.56666667]
#  [ 187.46666667  202.68333333]
#  [ 238.53333333  248.46666667]
#  [ 261.26666667  269.1       ]
#  [ 281.53333333  289.73333333]
#  [ 306.26666667  311.75      ]
#  [ 332.11666667  341.8       ]
#  [ 346.76666667  360.36666667]
#  [ 390.45        396.01666667]
#  [ 401.71666667  407.58333333]
#  [ 427.26666667  433.48333333]
#  [ 438.01666667  444.78333333]
#  [ 530.88333333  537.        ]
#  [ 540.63333333  547.75      ]
#  [ 563.68333333  570.01666667]
#  [ 577.41666667  585.76666667]
#  [ 591.48333333  602.25      ]
#  [ 606.2         612.4       ]
#  [ 631.71666667  637.93333333]
#  [ 654.95        660.48333333]
#  [ 678.8         686.35      ]
#  [ 697.15        704.31666667]
#  [ 712.55        718.71666667]
#  [ 722.5         728.78333333]
#  [ 748.6         760.75      ]
#  [ 769.38333333  775.31666667]
#  [ 804.88333333  810.88333333]
#  [ 815.76666667  821.61666667]
#  [ 844.66666667  853.53333333]
#  [ 878.86666667  884.4       ]
#  [1069.58333333 1074.36666667]
#  [1077.93333333 1086.85      ]
#  [1099.38333333 1106.61666667]
#  [1112.06666667 1119.8       ]
#  [1139.76666667 1145.23333333]
#  [1150.66666667 1157.13333333]
#  [1166.58333333 1173.33333333]]

# %%
print(pos)
# Out:
# <AnalogSignalArray at 0x7fdbc9662250: 1 signals (2 segments)> for a total of 41:50 minutes

# %%
import nelpy.plotting as npl
# Set default figure aesthetics
npl.setup(font_scale=1)

with npl.FigureManager(show=True, figsize=(6, 6)) as (fig, ax):
    npl.utils.skip_if_no_output(fig)

    tvals, vals = pos[[0,1],:].asarray() # Access timestamps and channel data as numpy arrays
    xvals, yvals = vals # Access two channels as x and y
    ax.plot(xvals, yvals, lw=0.5, c='0.3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [41], in <cell line: 5>()
#       6 npl.utils.skip_if_no_output(fig)
#       8 tvals, vals = pos[[0,1],:].asarray() # Access timestamps and channel data as numpy arrays
# ----> 9 xvals, yvals = vals # Access two channels as x and y
#      10 ax.plot(xvals, yvals, lw=0.5, c='0.3')
#
# ValueError: too many values to unpack (expected 2)
